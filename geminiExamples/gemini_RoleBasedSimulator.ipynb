# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.11.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.10.5)

# %%
import google.generativeai as genai

API_KEY=open("gemini_key.txt", "r").read()

#Configure GEMINI API KEY
genai.configure(api_key = API_KEY)

#Initialize the Gemini Model
model = genai.GenerativeModel("gemini-2.0-flash")

#Role-Based Prompt Builder
def build_prompt(role, query):
  role = role.lower()
  if role == "tutor":
    return f"you are a helpful tutor. Explain the following concept clearly:\n{query}"
  elif role == "career_counselor":
    return f"you are a helpful career counselor. Advise a student interested in:\n{query}"
  elif role == "assistant":
    return f"you are a smart assistant. Help with the following requests:\n{query}"
  else:
    return f"you are a general-purpose AI. Response to:\n{query}"

# %%
#Generating reponse using Gemini
def generate_response(role, query):
  prompt = build_prompt(role, query)
  response = model.generate_content(prompt)
  return response.text

# %%
#Example 1
print(generate_response("tutor", "what is overfitting in machine learning?"))
# Out:
# Alright, let's break down the concept of overfitting in machine learning in a way that's easy to understand.
#
# **Imagine this:**
#
# You're studying for a history test.  Instead of understanding the broad historical trends and causes, you memorize *every single fact and date* from the textbook. You ace that particular test because you can regurgitate everything perfectly. However, when the teacher asks a question that requires you to apply your knowledge to a new, slightly different scenario, you're completely lost. You only know the specific examples you memorized.
#
# **That's essentially what overfitting is in machine learning.**
#
# Here's a more formal explanation:
#
# **Overfitting Definition**
#
# *   **Overfitting** occurs when a machine learning model learns the training data *too well*. It essentially memorizes the noise, specific examples, and irrelevant details within the training data, instead of learning the underlying, general patterns that would allow it to generalize well to new, unseen data.
#
# **Key Characteristics of an Overfit Model:**
#
# 1.  **High Accuracy on Training Data:** The model performs exceptionally well on the data it was trained on. It might even achieve close to 100% accuracy.  This is because it has essentially "memorized" the training set.
#
# 2.  **Poor Generalization to New Data (High Error on Test Data):**  When the model is presented with new, unseen data (often called the "test data" or "validation data"), its performance drops significantly. It can't accurately predict or classify new examples because it hasn't learned the fundamental principles.
#
# 3.  **Complex Model:** Overfit models are often overly complex. They might have too many parameters, too many layers (in neural networks), or too high a degree polynomial (in regression).  This complexity allows them to "fit" the noise in the training data.
#
# **Why does Overfitting Happen?**
#
# *   **Small Training Dataset:** When you have a small amount of training data, the model has a higher chance of learning the noise and specific instances rather than the underlying patterns.
# *   **Overly Complex Model:**  A very powerful model (e.g., a deep neural network with many layers or a high-degree polynomial regression) has the capacity to learn extremely intricate relationships, including noise.
# *   **Training for Too Long:**  Sometimes, even with a good dataset and model, training for an excessive number of iterations can lead to overfitting.  The model continues to refine its parameters, eventually fitting the noise.
#
# **How to Detect Overfitting**
#
# The most common way to detect overfitting is to compare the model's performance on the training data and a separate **validation** or **test** dataset.
#
# *   **If the model performs significantly better on the training data than on the validation/test data, it's a strong indication of overfitting.**
#
# **Visual Clues (depending on the type of model):**
#
# *   **Decision Trees:** A very deep decision tree with many branches and leaves is likely to be overfit.
# *   **Regression:** A high-degree polynomial regression that perfectly fits every data point in the training set but oscillates wildly between them is a classic example of overfitting.
#
# **How to Prevent/Reduce Overfitting**
#
# There are several techniques you can use to combat overfitting:
#
# 1.  **Increase Training Data:**  The more data you have, the harder it is for the model to memorize noise and the easier it is for it to learn general patterns.  This is often the most effective solution.
#
# 2.  **Simplify the Model (Regularization):**
#
#     *   **Regularization Techniques (L1/L2 Regularization):**  These techniques add a penalty to the model's cost function for having large weights (coefficients). This encourages the model to use smaller weights, effectively simplifying it.  L1 regularization can even lead to some weights being set exactly to zero, performing feature selection.
#     *   **Early Stopping:** Monitor the model's performance on a validation set during training. Stop training when the performance on the validation set starts to degrade (even if the training set performance is still improving).
#     *   **Pruning (for Decision Trees):** Reduce the size of a decision tree by removing branches that don't significantly improve performance.
#
# 3.  **Cross-Validation:** Use techniques like k-fold cross-validation to more reliably estimate the model's performance on unseen data. This provides a more robust estimate of how well the model generalizes.
#
# 4.  **Feature Selection/Engineering:**
#
#     *   **Feature Selection:** Carefully choose which features to include in the model.  Irrelevant or redundant features can contribute to overfitting.
#     *   **Feature Engineering:** Create new, more informative features from the existing ones.
#
# 5.  **Dropout (for Neural Networks):**  During training, randomly "drop out" (ignore) some neurons. This forces the network to learn more robust representations that don't rely on any single neuron.
#
# **In Summary**
#
# Overfitting is a common problem in machine learning where a model learns the training data too well, leading to poor generalization on new data. It's important to detect and prevent overfitting by using techniques like increasing training data, simplifying the model, and using regularization. The goal is to create a model that captures the underlying patterns in the data without memorizing the noise.

# %%
#Example 2
print(generate_response("career_counselor","data science career options"))
# Out:
# Okay, let's explore the exciting world of Data Science and find the right path for you! Data Science is a broad field, so the more specific we can get about your interests and skills, the better I can advise you. Let's start with some general advice and then we can dive deeper based on your answers.
#
# **First, some crucial things to consider regardless of the specific path:**
#
# *   **What are you *actually* interested in?** Data Science is often glamorized, but the day-to-day work can vary dramatically.  Do you enjoy:
#     *   **The statistical rigor of analyzing data?**
#     *   **The programming and engineering side of building models?**
#     *   **The communication and storytelling aspects of explaining insights?**
#     *   **Solving specific problems, like in healthcare, finance, or marketing?**
# *   **What are your strongest skills?**  Be honest with yourself!  Are you:
#     *   **A math whiz?**  (Statistics, linear algebra, calculus are very helpful)
#     *   **A coding ninja?** (Python and R are essential, but others might be useful depending on the field)
#     *   **A great communicator?** (Can you explain complex ideas simply?)
#     *   **A creative problem-solver?**
# *   **What are your long-term career goals?** Where do you see yourself in 5-10 years? Do you aspire to:
#     *   **Lead a data science team?**
#     *   **Become a subject matter expert in a specific domain?**
#     *   **Focus on research and development?**
#     *   **Start your own company?**
#
# **Now, let's look at some common Data Science career options:**
#
# **1. Data Scientist (General):**
#
# *   **Description:**  The classic Data Scientist role.  Involves the full lifecycle of a data project: collecting, cleaning, analyzing, modeling, and visualizing data to extract insights and solve business problems.
# *   **Skills:**  Strong in statistics, machine learning, programming (Python/R), data visualization (Tableau, Power BI), and communication.
# *   **Industries:**  Virtually every industry employs Data Scientists.
# *   **Example Tasks:** Building a churn prediction model for a subscription service, analyzing customer segmentation data to improve marketing campaigns.
#
# **2. Machine Learning Engineer (MLE):**
#
# *   **Description:** Focuses on building, deploying, and maintaining machine learning models in production environments.  Bridges the gap between research and application.
# *   **Skills:**  Strong programming skills (Python, Java, C++), deep understanding of machine learning algorithms, experience with cloud platforms (AWS, Azure, GCP), and DevOps principles.  Knowledge of MLOps is a big plus.
# *   **Industries:**  Tech companies, software development, companies building AI-powered products.
# *   **Example Tasks:**  Deploying a fraud detection model on a real-time transaction processing system, building a recommendation engine for an e-commerce website.
#
# **3. Data Analyst:**
#
# *   **Description:**  Focuses on analyzing existing data to identify trends, patterns, and insights that can inform business decisions. Often uses SQL, spreadsheets, and data visualization tools.
# *   **Skills:**  SQL, data visualization (Tableau, Power BI), strong analytical skills, business acumen, and communication.
# *   **Industries:**  All industries.
# *   **Example Tasks:**  Analyzing website traffic to identify areas for improvement, creating reports on sales performance, conducting market research.
#
# **4. Business Intelligence (BI) Analyst:**
#
# *   **Description:** Similar to a data analyst, but with a stronger focus on creating dashboards, reports, and visualizations to track key performance indicators (KPIs) and monitor business performance.
# *   **Skills:**  SQL, data warehousing concepts, data visualization tools (Tableau, Power BI, Qlik), strong understanding of business metrics.
# *   **Industries:**  All industries.
# *   **Example Tasks:**  Creating a sales dashboard that tracks revenue, customer acquisition cost, and churn rate, building reports on operational efficiency.
#
# **5. Data Engineer:**
#
# *   **Description:**  Focuses on building and maintaining the infrastructure that supports data collection, storage, processing, and analysis.  Deals with big data technologies and data pipelines.
# *   **Skills:**  Strong programming skills (Python, Java, Scala), experience with big data technologies (Hadoop, Spark, Kafka), cloud platforms (AWS, Azure, GCP), and databases (SQL, NoSQL).
# *   **Industries:**  Tech companies, data-driven organizations, companies with large datasets.
# *   **Example Tasks:**  Building a data pipeline to ingest data from multiple sources into a data warehouse, setting up and maintaining a Hadoop cluster, optimizing database performance.
#
# **6. Research Scientist (Data Science/Machine Learning):**
#
# *   **Description:**  Focuses on conducting research and developing new algorithms and techniques in the field of data science and machine learning.
# *   **Skills:**  Strong mathematical background (statistics, linear algebra, calculus), deep understanding of machine learning algorithms, research experience, and excellent programming skills.  Often requires a PhD.
# *   **Industries:**  Research institutions, universities, tech companies with research divisions.
# *   **Example Tasks:**  Developing a new deep learning architecture for image recognition, researching new methods for anomaly detection.
#
# **7. Data Architect:**
#
# *   **Description:** Designs and manages the data infrastructure for an organization, ensuring that data is readily available, secure, and reliable.
# *   **Skills:** Deep understanding of data modeling, data warehousing, data integration, and data governance principles. Experience with various database technologies and cloud platforms.
# *   **Industries:** Large enterprises, technology companies.
# *   **Example Tasks:** Designing a data warehouse for a large retail company, developing a data governance strategy for a financial institution.
#
# **How to Get There:**
#
# *   **Education:** A bachelor's degree in a quantitative field (e.g., Computer Science, Statistics, Mathematics, Economics) is often a good starting point. A master's degree in Data Science, Statistics, or a related field is often preferred, especially for more advanced roles.
# *   **Skills Development:**
#     *   **Programming:**  Master Python and/or R.  Focus on libraries like scikit-learn, pandas, NumPy, TensorFlow, PyTorch.
#     *   **Statistics:**  Brush up on statistical concepts like hypothesis testing, regression, and probability.
#     *   **Machine Learning:**  Learn the fundamentals of machine learning algorithms and their applications.
#     *   **Data Visualization:**  Become proficient with tools like Tableau, Power BI, or Matplotlib.
#     *   **Databases:**  Learn SQL and NoSQL databases.
#     *   **Cloud Computing:**  Familiarize yourself with cloud platforms like AWS, Azure, or GCP.
# *   **Projects:**  Build a portfolio of projects that demonstrate your skills.  This is *crucial*!  Look for interesting datasets online (Kaggle is a great resource) and try to solve a real-world problem.  Put your projects on GitHub.
# *   **Internships:**  Gain practical experience through internships.  This is the best way to learn about the day-to-day work and network with professionals in the field.
# *   **Networking:**  Attend industry events, join online communities, and connect with data scientists on LinkedIn.
#
# **To help me give you more personalized advice, please tell me more about:**
#
# *   **Your academic background (major, courses you've enjoyed).**
# *   **Any prior experience you have with data analysis, programming, or statistics (even if it's just from coursework).**
# *   **What aspects of data science most interest you (e.g., machine learning, data visualization, big data).**
# *   **What industries you're interested in working in (e.g., healthcare, finance, tech).**
# *   **What your career goals are?**
# *   **How much time do you have available to prepare for your Data Science career?**
#
# Once I have this information, I can give you more tailored advice on what skills to focus on, what types of projects to build, and what career paths might be a good fit for you. Good luck! Let's make your Data Science dreams a reality.

# %%
#Example 3
print(generate_response("assistant","latest trends in generative AI"))
# Out:
# Okay, I can help you with that! Generative AI is a rapidly evolving field, so the "latest" trends are practically changing week to week. However, here's a breakdown of some of the most prominent and exciting trends right now, categorized for clarity:
#
# **I.  Fundamental Model Improvements & Architectures:**
#
# *   **Mixture of Experts (MoE) Architectures becoming mainstream:** This architecture, where different parts of the model specialize in different tasks, is increasingly being adopted. This leads to larger, more capable models without proportionally increasing computational cost during inference.  Expect to see more models using MoE, enabling breakthroughs in complex reasoning and multimodal capabilities.
# *   **Retrieval-Augmented Generation (RAG) Refinement:** RAG is evolving beyond simple document retrieval. Trends include:
#     *   **More Sophisticated Retrieval:** Moving beyond keyword-based search to semantic search, graph-based retrieval, and hybrid approaches.
#     *   **Recursive Retrieval:** Breaking down queries into sub-queries and iteratively refining the retrieved context.
#     *   **Context Optimization:** Learning to select the most relevant snippets from retrieved documents and re-ranking them for optimal use.
#     *   **Modular RAG pipelines:** More complex pipelines integrating various retrieval and generation components.
# *   **Continued focus on efficiency:** Techniques like distillation, quantization, and pruning are being actively explored to make large models smaller, faster, and more accessible.  This is crucial for deploying models on edge devices and reducing cloud costs.
# *   **Longer Context Windows:**  Models are now capable of processing and reasoning over significantly longer sequences of text (hundreds of thousands or even millions of tokens).  This allows for more complex tasks that require understanding larger documents, codebases, or conversations.  The challenge is maintaining performance and coherence across these extended contexts.
# *   **Attention Mechanism Innovation:** Alternatives and improvements to the standard Transformer attention mechanism are being explored to address its computational complexity and limitations with long sequences.  Examples include linear attention, sparse attention, and recurrent attention mechanisms.
#
# **II.  Multimodal AI Advancements:**
#
# *   **Text-to-Video:**  Generating realistic and coherent videos from text prompts is improving rapidly.  New models are emerging with better control over style, composition, and motion.
# *   **Text-to-3D:**  Creating 3D models from text is becoming more accessible and sophisticated.  Applications include game development, product design, and virtual reality.
# *   **Audio Generation (Text-to-Speech, Music Generation, Sound Effects):**  Generating high-quality audio is another hot area.  This includes realistic text-to-speech, music composition, and the creation of sound effects for various applications.
# *   **Image Editing and Manipulation:**  Generative models are enabling powerful image editing capabilities, such as object inpainting, style transfer, and realistic image manipulation.
# *   **Multimodal Reasoning and Understanding:**  Models are being developed that can reason across different modalities (e.g., understanding the relationship between an image and its caption).  This is crucial for tasks like visual question answering and multimodal dialogue.
# *   **Integration of Modalities:**  The ability to seamlessly combine and integrate different modalities (text, image, audio, video) is a major focus. This will lead to more versatile and powerful AI systems.
#
# **III.  Applications & Use Cases:**
#
# *   **AI-powered Content Creation:**  Generative AI is transforming content creation across various domains, including:
#     *   **Marketing:** Generating ad copy, social media posts, and product descriptions.
#     *   **Education:** Creating personalized learning materials and interactive simulations.
#     *   **Entertainment:** Generating scripts, music, and visual effects.
# *   **Code Generation and Completion:**  AI is becoming increasingly proficient at generating code, assisting developers with tasks like code completion, bug detection, and code translation.  This can significantly improve developer productivity.
# *   **Drug Discovery and Materials Science:**  Generative models are being used to design new drug candidates and materials with specific properties.
# *   **Personalized Medicine:**  AI is being used to generate personalized treatment plans and predict patient outcomes.
# *   **Virtual Assistants and Chatbots:**  Generative AI is enabling more natural and engaging conversations with virtual assistants and chatbots.  This is leading to more effective customer service and personalized experiences.
# *   **Simulation and Training:**  Generative models are being used to create realistic simulations for training in various fields, such as healthcare, aviation, and manufacturing.
# *   **Robotics:**  Generative AI is being used to train robots to perform complex tasks in unstructured environments.
#
# **IV.  Ethical Considerations & Challenges:**
#
# *   **Bias and Fairness:**  Addressing biases in training data and ensuring that generative models produce fair and equitable outputs remains a critical challenge.
# *   **Misinformation and Deepfakes:**  The ability to generate realistic fake content raises concerns about the spread of misinformation and the potential for malicious use.  Developing methods to detect and mitigate deepfakes is essential.
# *   **Copyright and Intellectual Property:**  The legal implications of using generative models to create content are still being debated.  Questions about ownership, attribution, and copyright infringement need to be addressed.
# *   **Job Displacement:**  The automation potential of generative AI raises concerns about job displacement in certain industries.  Strategies for mitigating these impacts and retraining workers are needed.
# *   **Explainability and Interpretability:**  Understanding how generative models make decisions is important for building trust and ensuring accountability.  Developing methods to explain and interpret the outputs of these models is an active area of research.
# *   **Security and Privacy:** Ensuring the security of generative models and protecting the privacy of user data is crucial.
#
# **V. Key Enabling Technologies & Trends driving further growth:**
#
# *   **Reinforcement Learning from Human Feedback (RLHF):** Continues to be refined as the main method for aligning models to human preferences. Improvements in RLHF are leading to more controllable and safer models.
# *   **Synthetic Data Generation:** Creating synthetic data to augment or replace real-world data is becoming increasingly popular. This can help to address data scarcity, bias, and privacy concerns.
# *   **Edge Computing:**  Deploying generative models on edge devices (e.g., smartphones, IoT devices) is becoming more feasible due to advances in model compression and hardware acceleration.
# *   **AI Accelerators (GPUs, TPUs, etc.):**  Continued advancements in hardware acceleration are enabling faster training and inference of generative models.
# *   **Open Source Models and Tools:**  The increasing availability of open-source models and tools is democratizing access to generative AI and accelerating innovation.
#
# **To stay up-to-date, I recommend following these resources:**
#
# *   **Arxiv and other research paper repositories:** Keep an eye on the latest research papers in the field.
# *   **AI conferences (NeurIPS, ICML, ICLR, CVPR, ICCV, ACL):** These conferences showcase the latest breakthroughs in generative AI.
# *   **AI blogs and newsletters (e.g., OpenAI blog, Google AI blog, DeepMind blog, The Batch by Andrew Ng):** These resources provide updates on the latest trends and developments.
# *   **AI communities and forums (e.g., Reddit's r/MachineLearning, Stack Overflow):** These communities are a great place to discuss the latest trends and ask questions.
# *   **Twitter:** Follow leading AI researchers, practitioners, and organizations on Twitter.
# *   **Venture Capital and Startup News:** Pay attention to which companies are getting funded and what problems they are tackling with GenAI.
#
# This is just a snapshot of the current trends in generative AI. The field is constantly evolving, so it's important to stay informed and adapt to the latest developments. Good luck exploring this exciting area! Let me know if you have any more specific questions.

# %%
#Example 4
print(generate_response("doctor","what should i do if i have a headache"))
# Out:
# Okay, here's a breakdown of what you can do if you have a headache, ranging from simple home remedies to when you should seek medical attention:
#
# **1. Immediate Actions (Home Remedies):**
#
# *   **Hydrate:** Dehydration is a common headache trigger. Drink a glass of water right away and continue to sip throughout the next hour.
# *   **Rest:** Find a quiet, dark room and lie down. Close your eyes and try to relax.
# *   **Temperature Therapy:**
#     *   **Cool Compress:** Apply a cold compress or ice pack wrapped in a towel to your forehead or temples for 15-20 minutes.
#     *   **Warm Compress/Shower:** Some people find relief with a warm compress on the back of their neck or a warm shower. Experiment to see what works best for you.
# *   **Gentle Massage:** Gently massage your temples, forehead, neck, and shoulders.
# *   **Caffeine (Carefully):** If you're a regular caffeine consumer, a small amount of caffeine (like a cup of coffee or tea) might help, as caffeine withdrawal can cause headaches. However, too much caffeine can also *cause* headaches, so be mindful of your intake. If you don't normally consume caffeine, it may not be a good idea to start.
# *   **Over-the-Counter (OTC) Pain Relievers:**
#     *   **Acetaminophen (Tylenol):** Follow the dosage instructions on the label.
#     *   **Ibuprofen (Advil, Motrin):** Follow the dosage instructions on the label.  Take with food to avoid stomach upset.
#     *   **Naproxen (Aleve):** Follow the dosage instructions on the label.
#     *   **Aspirin:** Follow the dosage instructions on the label. *Aspirin should not be given to children or teenagers due to the risk of Reye's syndrome.*
#
# **2. Identifying Potential Triggers:**
#
# *   **Food and Drinks:** Keep a food diary to see if certain foods (aged cheese, processed meats, chocolate, alcohol, etc.) seem to trigger your headaches.
# *   **Stress:** Are you under a lot of stress lately? Stress management techniques (see below) can be helpful.
# *   **Sleep:** Are you getting enough sleep? Aim for 7-9 hours of quality sleep per night.
# *   **Posture:** Poor posture can contribute to headaches. Make sure your workstation is ergonomically correct.
# *   **Environment:** Are you exposed to strong smells, loud noises, or bright lights?
# *   **Dehydration:** As mentioned above, ensure you are properly hydrated
# *   **Medications:** Are you taking any medications that may have headaches as a side effect? Review this with your doctor or pharmacist.
#
# **3. Longer-Term Strategies and Prevention:**
#
# *   **Stress Management:** Practice relaxation techniques like deep breathing exercises, meditation, yoga, or progressive muscle relaxation.
# *   **Regular Exercise:** Regular physical activity can help reduce stress and improve overall health, which can help prevent headaches.
# *   **Maintain a Regular Sleep Schedule:** Go to bed and wake up around the same time each day, even on weekends.
# *   **Eat Regular Meals:** Don't skip meals, as low blood sugar can trigger headaches.
# *   **Stay Hydrated:** Drink plenty of water throughout the day.
# *   **Limit Caffeine and Alcohol:** As mentioned earlier, both can be headache triggers.
# *   **Ergonomics:** Ensure your workspace is set up correctly to promote good posture.
# *   **Consider a Headache Diary:** Track your headaches, including the date, time, duration, severity, potential triggers, and what you did to relieve them. This can help you identify patterns and triggers.
#
# **4. When to See a Doctor:**
#
# It's important to see a doctor if you experience any of the following:
#
# *   **Sudden, severe headache:** Especially if it comes on like a "thunderclap." This could indicate a serious condition like a subarachnoid hemorrhage.
# *   **Headache with fever, stiff neck, rash, confusion, seizures, vision changes, weakness, numbness, or difficulty speaking.** These could be signs of meningitis or other serious infections.
# *   **Headache after a head injury.**
# *   **A headache that is different or worse than your usual headaches.**
# *   **Headaches that are becoming more frequent or severe.**
# *   **Headaches that don't respond to over-the-counter pain relievers.**
# *   **Headaches that interfere with your daily activities.**
# *   **New headaches, especially if you are over 50 years old.**
# *   **Headaches accompanied by pain or redness in one eye.**
# *   **Headaches that get worse when you lie down or strain.**
#
# **Important Considerations:**
#
# *   **This information is not a substitute for professional medical advice.** Always consult with your doctor or other qualified healthcare provider if you have any questions about your health or a medical condition.
# *   **If you are pregnant or breastfeeding, talk to your doctor before taking any medications, including over-the-counter pain relievers.**
# *   **Children and teenagers should not take aspirin without consulting a doctor.**
#
# To give you more tailored advice, it would be helpful to know:
#
# *   How often do you get headaches?
# *   How severe are they?
# *   Where is the pain located?
# *   Do you have any other symptoms?
# *   Have you had headaches like this before?
# *   What have you already tried to relieve the headache?
#
# I hope this helps you feel better soon!
